# %% [markdown]
# # Scatterplot

# %%
head(mtcars)
# Out:
#                   mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag     21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive    21.4 6   258  110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.440 17.02 0  0  3    2
# Valiant           18.1 6   225  105 2.76 3.460 20.22 1  0  3    1

# %%
library(ggplot2)

# %%
pairs(~ ., data = mtcars)
# Out:
# plot without title

# %%
plotCols <- c("cyl")#,
              #"disp",
              #"hp",
              #"drat",
              #"wt",
              #"qsec")

# %%
carfr <- data.frame(mtcars[plotCols])

# %%
plotEE <- function(x){
  title <- paste("mpg vs", x, "\n (newline)")
  ggplot(carfr, aes_string(x, "mpg")) +
    geom_point() +
   facet_grid(OverallHeight ~ Orientation) +
    ggtitle(title) +
    stat_smooth(method = "lm")
}
lapply(plotCols, plotEE)
# Out:
# Error in layout_base(data, rows, drop = drop): At least one layer must contain all variables used for facetting
# Traceback:
#
# 1. prepare_mimebundle(obj, .self$handle_display_error)
# 2. repr_text(obj)
# 3. repr_text.default(obj)
# 4. paste(utils::capture.output(print(obj)), collapse = "\n")
# 5. utils::capture.output(print(obj))
# 6. evalVis(expr)
# 7. withVisible(eval(expr, pf))
# 8. eval(expr, pf)
# 9. eval(expr, envir, enclos)
# 10. print(obj)
# 11. print.default(obj)
# 12. print(structure(list(data = structure(list(cyl = c(6, 6, 4, 6,
#   . 8, 6, 8, 4, 4, 6, 6, 8, 8, 8, 8, 8, 8, 4, 4, 4, 4, 8, 8, 8, 8,
#   . 4, 4, 4, 8, 6, 8, 4)), .Names = "cyl", row.names = c("Mazda RX4",
#   . "Mazda RX4 Wag", "Datsun 710", "Hornet 4 Drive", "Hornet Sportabout",
#   . "Valiant", "Duster 360", "Merc 240D", "Merc 230", "Merc 280",
#   . "Merc 280C", "Merc 450SE", "Merc 450SL", "Merc 450SLC", "Cadillac Fleetwood",
#   . "Lincoln Continental", "Chrysler Imperial", "Fiat 128", "Honda Civic",
#   . "Toyota Corolla", "Toyota Corona", "Dodge Challenger", "AMC Javelin",
#   . "Camaro Z28", "Pontiac Firebird", "Fiat X1-9", "Porsche 914-2",
#   . "Lotus Europa", "Ford Pantera L", "Ferrari Dino", "Maserati Bora",
#   . "Volvo 142E"), class = "data.frame"), layers = list(<environment>,
#   .     <environment>), scales = <S4 object of class structure("Scales", package = "ggplot2")>,
#   .     mapping = structure(list(x = cyl, y = mpg), .Names = c("x",
#   .     "y"), class = "uneval"), theme = list(), coordinates = structure(list(
#   .         limits = structure(list(x = NULL, y = NULL), .Names = c("x",
#   .         "y"))), .Names = "limits", class = c("cartesian", "coord"
#   .     )), facet = structure(list(rows = structure(list(OverallHeight), env = <environment>, class = "quoted"),
#   .         cols = structure(list(Orientation), env = <environment>, class = "quoted"),
#   .         margins = FALSE, free = structure(list(x = FALSE, y = FALSE), .Names = c("x",
#   .         "y")), space_free = structure(list(x = FALSE, y = FALSE), .Names = c("x",
#   .         "y")), labeller = "label_value", as.table = TRUE, drop = TRUE,
#   .         shrink = TRUE), .Names = c("rows", "cols", "margins",
#   .     "free", "space_free", "labeller", "as.table", "drop", "shrink"
#   .     ), class = c("grid", "facet")), plot_env = <environment>,
#   .     labels = structure(list(title = "mpg vs cyl \n (newline)",
#   .         x = "cyl", y = "mpg"), .Names = c("title", "x", "y"))), .Names = c("data",
#   . "layers", "scales", "mapping", "theme", "coordinates", "facet",
#   . "plot_env", "labels"), class = c("gg", "ggplot")))
# 13. print.ggplot(structure(list(data = structure(list(cyl = c(6,
#   . 6, 4, 6, 8, 6, 8, 4, 4, 6, 6, 8, 8, 8, 8, 8, 8, 4, 4, 4, 4, 8,
#   . 8, 8, 8, 4, 4, 4, 8, 6, 8, 4)), .Names = "cyl", row.names = c("Mazda RX4",
#   . "Mazda RX4 Wag", "Datsun 710", "Hornet 4 Drive", "Hornet Sportabout",
#   . "Valiant", "Duster 360", "Merc 240D", "Merc 230", "Merc 280",
#   . "Merc 280C", "Merc 450SE", "Merc 450SL", "Merc 450SLC", "Cadillac Fleetwood",
#   . "Lincoln Continental", "Chrysler Imperial", "Fiat 128", "Honda Civic",
#   . "Toyota Corolla", "Toyota Corona", "Dodge Challenger", "AMC Javelin",
#   . "Camaro Z28", "Pontiac Firebird", "Fiat X1-9", "Porsche 914-2",
#   . "Lotus Europa", "Ford Pantera L", "Ferrari Dino", "Maserati Bora",
#   . "Volvo 142E"), class = "data.frame"), layers = list(<environment>,
#   .     <environment>), scales = <S4 object of class structure("Scales", package = "ggplot2")>,
#   .     mapping = structure(list(x = cyl, y = mpg), .Names = c("x",
#   .     "y"), class = "uneval"), theme = list(), coordinates = structure(list(
#   .         limits = structure(list(x = NULL, y = NULL), .Names = c("x",
#   .         "y"))), .Names = "limits", class = c("cartesian", "coord"
#   .     )), facet = structure(list(rows = structure(list(OverallHeight), env = <environment>, class = "quoted"),
#   .         cols = structure(list(Orientation), env = <environment>, class = "quoted"),
#   .         margins = FALSE, free = structure(list(x = FALSE, y = FALSE), .Names = c("x",
#   .         "y")), space_free = structure(list(x = FALSE, y = FALSE), .Names = c("x",
#   .         "y")), labeller = "label_value", as.table = TRUE, drop = TRUE,
#   .         shrink = TRUE), .Names = c("rows", "cols", "margins",
#   .     "free", "space_free", "labeller", "as.table", "drop", "shrink"
#   .     ), class = c("grid", "facet")), plot_env = <environment>,
#   .     labels = structure(list(title = "mpg vs cyl \n (newline)",
#   .         x = "cyl", y = "mpg"), .Names = c("title", "x", "y"))), .Names = c("data",
#   . "layers", "scales", "mapping", "theme", "coordinates", "facet",
#   . "plot_env", "labels"), class = c("gg", "ggplot")))
# 14. ggplot_build(x)
# 15. train_layout(panel, plot$facet, layer_data, plot$data)
# 16. facet_train_layout(facet, c(list(plot_data), data))
# 17. facet_train_layout.grid(facet, c(list(plot_data), data))
# 18. layout_grid(data, facet$rows, facet$cols, facet$margins, drop = facet$drop,
#   .     as.table = facet$as.table)
# 19. layout_base(data, rows, drop = drop)
# 20. stop("At least one layer must contain all variables used for facetting")

# %% [markdown]
# # Residualplot (chi2)

# %%
ResidualPlotFunction <- function(dt){
    options(warn=-1)
my.chi <- chisq.test(dt) #perform chisq test
df.chi <- as.data.frame.matrix(my.chi$residuals) #transform to df
df.chi["res"]  <- rownames(df.chi) #index
df.chi <- melt( df.chi, id.vars="res", value.name="residuals", variable.name="als") #transform to LONG format
p <- ggplot(df.chi, aes(x= als, y= res), fill = residuals) + theme(axis.title.x = element_blank(),axis.title.y = element_blank())+ geom_tile(aes(fill = residuals), colour = "white") + scale_fill_gradient2(low="steelblue", high="green", mid="white") +geom_text(aes(label=round(residuals,digits=2)), size=3) #scale_fill_gradient(low="steelblue", high="green") #geom_bar( position = "identity", stat = "identity", alpha = .3 )# + geom_tile(aes(fill = 'rescale'), colour = 'white') + scale_fill_gradient(low = 'white', high = 'steelblue')
    options(warn=0)
return(p)
}

# %%
library(MASS)
library(ggplot2)
library(reshape2)
options(repr.plot.width=4, repr.plot.height=3)
tbl = table(survey$Smoke, survey$Exer); tbl; ResidualPlotFunction(tbl)
# Out:
#
#         Freq None Some
#   Heavy    7    1    3
#   Never   87   18   84
#   Occas   12    3    4
#   Regul    9    1    7
# plot without title
